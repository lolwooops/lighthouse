# %%
# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv',sep=',')
df.drop('#',axis=1,inplace=True)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Objective: Plot regression line between attack and defense

# %%
attack=df.Attack
defense=df.Defense

sns.lmplot(x='Attack',y='Defense',data=df)
plt.show()

# %% [markdown]
# # Objective: Plot regression line between attack and defense with respect to generation

# %%
sns.lmplot(x='Attack',y='Defense',data=df,hue="Generation")
plt.show()

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Objective: Make boxplot for each feature of dataframe (without Generation and Legendary features) in one plot

# %%
#plt.subplot()
# sns.boxplot(x="HP",y="Total",data=df)
# sns.boxplot(x="Attack",y="Total",data=df)
# sns.boxplot(x="Defense",y="Total",data=df)
# sns.boxplot(x="Sp. Atk",y="Total",data=df)
# sns.boxplot(x="Sp. Def",y="Total",data=df)
# sns.boxplot(x="Speed",y="Total",data=df)
col = [
    "Total",
    "HP",
    "Attack",
    "Defense",
    "Sp. Atk",
    "Sp. Def",
    "Speed"
]
df2 = df[col]
sns.boxplot(data=df2)

plt.show()

# %% [markdown]
# # Objective: Plot correlation heatmap of pokemon dataframe (not include features Generation and Legendary)

# %%
sns.heatmap(data=df2)
plt.show()

# %%
col3 = [
    "HP",
    "Attack",
    "Defense",
    "Sp. Atk",
    "Sp. Def",
    "Speed"
]
df3 = df[col3]
sns.heatmap(data=df3)
plt.show()
