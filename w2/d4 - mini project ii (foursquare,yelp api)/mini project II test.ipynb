# %%
import uuid
from IPython.display import display_javascript, display_html, display
import json

class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
        self.uuid = str(uuid.uuid4())

    def _ipython_display_(self):
        display_html('<div id="{}" style="height: 600px; width:100%;"></div>'.format(self.uuid), raw=True)
        display_javascript("""
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
        document.getElementById('%s').appendChild(renderjson(%s))
        });
        """ % (self.uuid, self.json_str), raw=True)
        
#RenderJSON(#json)

# %%
yelp_client_id = "BagZJOrnqKddLICuqFQeXw"
yelp_api = "tfUiSDCSapNaY3Bdg03l-aqMgFN4PpeW-TSLY-vhbV5mE_buz8pR6IUfndLtjhiNkIFl_XajJpAEDTJX4Vj8GW2FvSG1ZvKkZ-irjVNzajs57okH_1eKbhNQy4oAYHYx"


fs_id = "LI2VHLBCPFJEO1D1O5EMPDXA233B5QP4FGH442ERLK4INCNQ"
fs_s = "BAFOMI5B3PTIJFL5FVJIB0I4ZBQGXYXFPCAUQWHWT5EI3GWA"

# %%
import requests
import pandas as pd
import numpy as np
from IPython.display import JSON
import json
from pandas import json_normalize

# %%
#foursquare - calgary
url = "https://api.foursquare.com/v2/venues/explore?"
categoryId = "4bf58dd8d48988d1e0931735,4bf58dd8d48988d16d941735" #coffee shops + cafes
limit = "50"
offset = "50"
v = "20201231"

near = "Calgary,AB"
radius = "16000" #area of calgary = ~820km^2

param = f'near={near}&categoryId={categoryId}&radius={radius}&limit={limit}&sortByPopularity=1&v={v}&client_id={fs_id}&client_secret={fs_s}'
res = requests.get(url+param)
fs_c = res.json()

# %%
#RenderJSON(fs_c)

# %%
#foursquare - edmonton
near2 = "Edmonton,AB" 
radius2 = "14700" #area of edmonton = ~680km^2

param2 = f'near={near2}&categoryId={categoryId}&radius={radius2}&limit={limit}&v={v}&client_id={fs_id}&client_secret={fs_s}'
res2 = requests.get(url+param2)
fs_e = res2.json()

# %%
#foursquare - fort mac
near3 = "FortMcMurray,AB" 
radius3 = "4300" #area of edmonton = ~680km^2

param3 = f'near={near3}&categoryId={categoryId}&radius={radius3}&limit={limit}&v={v}&client_id={fs_id}&client_secret={fs_s}'
res3 = requests.get(url+param3)
fs_fm = res3.json()

# %%
#foursquare - Banff
near4 = "banff,AB" 
radius4 = "1200" #area of edmonton = ~680km^2

param4 = f'near={near3}&categoryId={categoryId}&radius={radius4}&limit={limit}&v={v}&client_id={fs_id}&client_secret={fs_s}'
res4 = requests.get(url+param4)
fs_b = res4.json()

# %%
#foursquare - Jasper
near5 = "Jasper,AB" 
radius5 = "1200" #area of edmonton = ~680km^2

param5 = f'near={near5}&categoryId={categoryId}&radius={radius5}&limit={limit}&v={v}&client_id={fs_id}&client_secret={fs_s}'
res5 = requests.get(url+param5)
fs_j = res5.json()

# %%
#foursquare - Red deer
near6 = "RedDeer,AB" 
radius6 = "4700" #area of edmonton = ~680km^2

param6 = f'near={near6}&categoryId={categoryId}&radius={radius6}&limit={limit}&v={v}&client_id={fs_id}&client_secret={fs_s}'
res6 = requests.get(url+param6)
fs_rd = res6.json()

# %%
#df fs calg
#fsc = json_normalize(data=fs_c['response']['groups'],record_path='items')

#df fs edm
#fse = json_normalize(data=fs_e['response']['groups'],record_path='items')

#df fs fm
#fsfm = json_normalize(data=fs_fm['response']['groups'],record_path='items')

#df fs b
#fsb = json_normalize(data=fs_b['response']['groups'],record_path='items')

#df fs j
#fsj = json_normalize(data=fs_j['response']['groups'],record_path='items')

#df fs rd
#fsrd = json_normalize(data=fs_rd['response']['groups'],record_path='items')

#df fs all
#dffs = pd.concat([fsc,fse,fsfm,fsb,fsj,fsrd],ignore_index=True)

# %%
# #more data for calg
# for i in range(7):
#     test = requests.get(f"https://api.foursquare.com/v2/venues/explore?near={near}&categoryId={categoryId}&radius={radius}&limit={limit}&offset={i}&sortByPopularity=1&v={v}&client_id={fs_id}&client_secret={fs_s}").json()
#     fsc = pd.concat([fsc,json_normalize(test['response']['groups'],record_path='items')])
    
# #more data for edm
# for j in range(7):
#     test2 = requests.get(f"https://api.foursquare.com/v2/venues/explore?near={near2}&categoryId={categoryId}&radius={radius2}&limit={limit}&offset={j}&sortByPopularity=1&v={v}&client_id={fs_id}&client_secret={fs_s}").json() 
#     fse = pd.concat([fse,json_normalize(test2['response']['groups'],record_path='items')])

# %%
#yelp from postman
#url2 = https://api.yelp.com/v3/businesses/search?location=Calgary,AB&radius=16000&limit=50&categories=coffee

#df yelp calg
with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yelpcalgarycoffee.json') as ycc:
    nestedycc = json.load(ycc)

yc = json_normalize(nestedycc,record_path='businesses')

#df yelp edm
with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yelpedmontoncoffee.json') as yec:
    nestedyec = json.load(yec)

ye = json_normalize(nestedyec,record_path='businesses')

#fm
with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yfm.json') as yfmc:
    nestedyfm = json.load(yfmc)

yfm = json_normalize(nestedyfm,record_path='businesses')

#b
with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yb.json') as ybc:
    nestedybc = json.load(ybc)

yb = json_normalize(nestedybc,record_path='businesses')

#j
with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yj.json') as yjc:
    nestedyjc = json.load(yjc)

yj = json_normalize(nestedyjc,record_path='businesses')

#rd
with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yrd.json') as yrdc:
    nestedyrdc = json.load(yrdc)

yrd = json_normalize(nestedyrdc,record_path='businesses')

# %%
#print(json.dumps(nestedycc, indent=4, sort_keys=True))

# %%
dfy = pd.concat([yc,ye,yfm,yb,yj,yrd],ignore_index=True)
dfy.head()
# Out:
#                        id                                  alias  \
# 0  _yIvVucQh5W84m3Pk4dndg               made-by-marcus-calgary-3
# 1  kqDqbs3fMKJ6GGrLfENnxA                 vendome-café-calgary-2
# 2  Wxt2kWy9lj5eRxIO469reA                analog-coffee-calgary-9
# 3  8JvdWiR7teLbNBTQ5WLsCg              monogram-coffee-calgary-2
# 4  sI-LiVd21IGZMUmu2bnjIw  gravity-espresso-and-wine-bar-calgary
#
#                           name  \
# 0               Made by Marcus
# 1                 Vendome Café
# 2                Analog Coffee
# 3              Monogram Coffee
# 4  Gravity Espresso & Wine Bar
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/yQ2fqB...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/fBC2Bs...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/koQRZ0...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/F64wDw...      False
# ...

# %%
dfy.groupby(['location.city'])['id'].count()
# Out:
# location.city
# Banff            12
# Calgary          50
# Edmonton         50
# Fort McMurray     4
# Jasper            6
# Red Deer         15
# Name: id, dtype: int64

# %%
#for downtown areas

with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/yedmdt.json') as yedtc:
    nestedyedtc = json.load(yedtc)

yedt = json_normalize(nestedyedtc,record_path='businesses')

with open('C:/Users/Tim/Desktop/lighthouse/w2/d4/ycalgdt.json') as ycdtc:
    nestedycdtc = json.load(ycdtc)

ycdt = json_normalize(nestedycdtc,record_path='businesses')

dftest = pd.concat([yedt,ycdt])
dftest.groupby(['location.city'])['id'].count()
# Out:
# location.city
# Calgary     50
# Edmonton    50
# Name: id, dtype: int64
